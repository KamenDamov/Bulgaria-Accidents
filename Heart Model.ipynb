# %%
#ML Model
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from textblob import TextBlob

# %%
df = pd.read_csv('2020vs2021.csv')

# %%
df.head()
# Out:
#           Области  ПТП, бр., 2021 г.  Загинали, бр., 2021 г.  \
# 0     БЛАГОЕВГРАД                274                      14
# 1          БУРГАС                396                      28
# 2           ВАРНА                550                      22
# 3  ВЕЛИКО ТЪРНОВО                218                      30
# 4           ВИДИН                 71                       6
#
#    Ранени, бр., 2021 г.  ПТП, бр., 2020 г.  Загинали, бр., 2020 г.  \
# 0                   390                249                      15
# 1                   538                367                      26
# 2                   686                569                      29
# 3                   265                218                      14
# 4                    86                 95                      14
#
#    Ранени, бр., 2020 г.  Разлика ПТП, бр.  Разлика ПТП, %  \
# 0                   320                25           10.04
# 1                   432                29            7.90
# ...

# %%
blob = TextBlob('Области').str.strip().translate(to='en')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-ab0038e39d37> in <module>
# ----> 1 blob = TextBlob('Области').str.strip().translate(to='en')
#       2 blob
#
# AttributeError: 'TextBlob' object has no attribute 'str'
